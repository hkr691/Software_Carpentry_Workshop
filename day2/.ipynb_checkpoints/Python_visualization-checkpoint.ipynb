# %%
from IPython.display import SVG

# %%
import pandas as pd

# %%
import pygal as pg

# %%
dem_health_data = pd.read_csv('Dem_Health_Full.txt', sep = '\t')

# %%
dem_health_data.head(25)
# Out:
#        County State  Population_Density  Poverty  Infant_Mortality  Suicide  \
# 0     Autauga    AL                  82     10.4               5.9     16.6
# 1     Baldwin    AL                 102     10.2               7.1     14.3
# 2     Barbour    AL                  32     22.1               7.1     10.3
# 3        Bibb    AL                  35     16.8               9.8     14.8
# 4      Blount    AL                  86     11.9               9.0     14.4
# 5     Bullock    AL                  18     26.2              13.3  -1111.1
# 6      Butler    AL                  27     20.0               5.8     11.9
# 7     Calhoun    AL                 184     16.4               9.5     13.6
# 8    Chambers    AL                  59     16.2               7.5     12.8
# 9    Cherokee    AL                  44     15.2               7.4     17.7
# 10    Chilton    AL                  60     14.9              10.5     13.3
# ...

# %%
dem_health_data.tail(10)
# Out:
#           County State  Population_Density  Poverty  Infant_Mortality  \
# 3131    Niobrara    WY                   1     14.1               NaN
# 3132        Park    WY                   4     11.7               3.9
# 3133      Platte    WY                   4     11.5               5.0
# 3134    Sheridan    WY                  11     11.5               4.8
# 3135    Sublette    WY                   1      7.7               8.7
# 3136  Sweetwater    WY                   4      8.6              10.2
# 3137       Teton    WY                   5      5.6               3.5
# 3138       Uinta    WY                  10     10.6               7.0
# 3139    Washakie    WY                   4     11.1               9.1
# 3140      Weston    WY                   3      9.9              11.7
#
#       Suicide  Total_Births  Total_Deaths
# 3131  -1111.1         254.0         307.0
# 3132     17.4        1281.0        1173.0
# 3133     22.2         901.0         983.0
# ...

# %%
help(dem_health_data)
# Out:
# Help on DataFrame in module pandas.core.frame object:
#
# class DataFrame(pandas.core.generic.NDFrame)
#  |  Two-dimensional size-mutable, potentially heterogeneous tabular data
#  |  structure with labeled axes (rows and columns). Arithmetic operations
#  |  align on both row and column labels. Can be thought of as a dict-like
#  |  container for Series objects. The primary pandas data structure
#  |
#  |  Parameters
#  |  ----------
#  |  data : numpy ndarray (structured or homogeneous), dict, or DataFrame
#  |      Dict can contain Series, arrays, constants, or list-like objects
#  |  index : Index or array-like
#  |      Index to use for resulting frame. Will default to np.arange(n) if
#  |      no indexing information part of input data and no index provided
#  |  columns : Index or array-like
#  |      Column labels to use for resulting frame. Will default to
#  |      np.arange(n) if no column labels are provided
#  |  dtype : dtype, default None
# ...

# %%
dir(dem_health_data)
# Out:
# ['County',
#  'Infant_Mortality',
#  'Population_Density',
#  'Poverty',
#  'State',
#  'Suicide',
#  'T',
#  'Total_Births',
#  'Total_Deaths',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
# ...

# %%
dem_health_data['State']
# Out:
# 0       AL
# 1       AL
# 2       AL
# 3       AL
# 4       AL
# 5       AL
# 6       AL
# 7       AL
# 8       AL
# 9       AL
# 10      AL
# 11      AL
# 12      AL
# 13      AL
# 14      AL
# 15      AL
# 16      AL
# 17      AL
# 18      AL
# 19      AL
# 20      AL
# 21      AL
# 22      AL
# 23      AL
# 24      AL
# 25      AL
# 26      AL
# 27      AL
# 28      AL
# 29      AL
#         ..
# 3111    WI
# 3112    WI
# 3113    WI
# 3114    WI
# 3115    WI
# 3116    WI
# 3117    WI
# 3118    WY
# 3119    WY
# 3120    WY
# 3121    WY
# 3122    WY
# 3123    WY
# 3124    WY
# 3125    WY
# 3126    WY
# 3127    WY
# 3128    WY
# 3129    WY
# 3130    WY
# 3131    WY
# 3132    WY
# 3133    WY
# 3134    WY
# 3135    WY
# 3136    WY
# 3137    WY
# 3138    WY
# 3139    WY
# 3140    WY
# Name: State, dtype: object

# %%
dem_health_data[['State', 'Poverty']]
# Out:
#      State  Poverty
# 0       AL     10.4
# 1       AL     10.2
# 2       AL     22.1
# 3       AL     16.8
# 4       AL     11.9
# 5       AL     26.2
# 6       AL     20.0
# 7       AL     16.4
# 8       AL     16.2
# 9       AL     15.2
# 10      AL     14.9
# 11      AL     18.7
# 12      AL     19.2
# 13      AL     14.0
# 14      AL     14.0
# 15      AL     13.7
# 16      AL     14.0
# 17      AL     22.0
# 18      AL     13.4
# 19      AL     17.5
# 20      AL     17.6
# 21      AL     13.3
# 22      AL     15.8
# 23      AL     25.0
# 24      AL     15.1
# 25      AL     12.5
# 26      AL     18.6
# 27      AL     15.7
# 28      AL     16.1
# 29      AL     17.4
# ...    ...      ...
# 3111    WI      9.7
# 3112    WI      4.6
# 3113    WI      4.1
# 3114    WI      7.4
# 3115    WI      9.6
# 3116    WI      7.5
# 3117    WI      7.8
# 3118    WY     14.4
# 3119    WY     13.2
# 3120    WY      7.9
# 3121    WY     12.2
# 3122    WY     10.5
# 3123    WY      8.5
# ...

# %%
dem_health_data.loc[0,:]
# Out:
# County                Autauga
# State                      AL
# Population_Density         82
# Poverty                  10.4
# Infant_Mortality          5.9
# Suicide                  16.6
# Total_Births             3048
# Total_Deaths             1867
# Name: 0, dtype: object

# %%
dem_health_data.loc[0,['Population_Density', 'Poverty']]
# Out:
# Population_Density      82
# Poverty               10.4
# Name: 0, dtype: object

# %%
dem_health_data.iloc[0,2:4]
# Out:
# Population_Density      82
# Poverty               10.4
# Name: 0, dtype: object

# %%
dem_health_data[(dem_health_data['State'] == 'AL') | (dem_health_data['State'] == 'TX')]
# Out:
#           County State  Population_Density  Poverty  Infant_Mortality  \
# 0        Autauga    AL                  82     10.4               5.9
# 1        Baldwin    AL                 102     10.2               7.1
# 2        Barbour    AL                  32     22.1               7.1
# 3           Bibb    AL                  35     16.8               9.8
# 4         Blount    AL                  86     11.9               9.0
# 5        Bullock    AL                  18     26.2              13.3
# 6         Butler    AL                  27     20.0               5.8
# 7        Calhoun    AL                 184     16.4               9.5
# 8       Chambers    AL                  59     16.2               7.5
# 9       Cherokee    AL                  44     15.2               7.4
# 10       Chilton    AL                  60     14.9              10.5
# 11       Choctaw    AL                  16     18.7              10.8
# ...

# %%
dem_health_data.iloc[3126]
dem_health_data.fillna(0, inplace=True)
dem_health_data.iloc[3126]
# Out:
# County                Hot Springs
# State                          WY
# Population_Density              2
# Poverty                      11.6
# Infant_Mortality                0
# Suicide                      23.9
# Total_Births                  437
# Total_Deaths                  627
# Name: 3126, dtype: object

# %%
dem_health_data['Suicide'].replace(-1111.1,0,inplace=True)

# %%
a_tuple = (1,2)

# %%
nested_list = [(1,2), (3,4)]
nested_list
# Out:
# [(1, 2), (3, 4)]

# %%
data_for_al = dem_health_data.loc[dem_health_data['State'] == 'AL', \
                                 ['Population_Density', 'Poverty']]
data_for_al.head()
# Out:
#    Population_Density  Poverty
# 0                  82     10.4
# 1                 102     10.2
# 2                  32     22.1
# 3                  35     16.8
# 4                  86     11.9

# %%
lst = [tuple(x) for x in data_for_al.values]

# %%
lst
# Out:
# [(82.0, 10.4),
#  (102.0, 10.199999999999999),
#  (32.0, 22.100000000000001),
#  (35.0, 16.800000000000001),
#  (86.0, 11.9),
#  (18.0, 26.199999999999999),
#  (27.0, 20.0),
#  (184.0, 16.399999999999999),
#  (59.0, 16.199999999999999),
#  (44.0, 15.199999999999999),
#  (60.0, 14.9),
#  (16.0, 18.699999999999999),
#  (22.0, 19.199999999999999),
#  (23.0, 14.0),
#  (26.0, 14.0),
#  (67.0, 13.699999999999999),
#  (92.0, 14.0),
#  (16.0, 22.0),
#  (17.0, 13.4),
#  (36.0, 17.5),
#  (23.0, 17.600000000000001),
#  (108.0, 13.300000000000001),
#  (87.0, 15.800000000000001),
#  (45.0, 25.0),
#  (86.0, 15.1),
#  (119.0, 12.5),
#  (40.0, 18.600000000000001),
#  (193.0, 15.699999999999999),
#  (29.0, 16.100000000000001),
#  (48.0, 17.399999999999999),
#  (45.0, 17.600000000000001),
#  (15.0, 24.899999999999999),
#  (28.0, 20.600000000000001),
#  (30.0, 16.300000000000001),
#  (162.0, 15.300000000000001),
#  (50.0, 14.5),
#  (591.0, 14.4),
#  (25.0, 16.100000000000001),
#  (131.0, 15.6),
# ...

# %%
scatter_plot = pg.XY(stroke = False)
scatter_plot.add('AL', lst)
SVG(scatter_plot.render())

# %%
scatter_plot = pg.XY(stroke = False)
scatter_plot.title = 'Population Density vs Poverty correlation'
scatter_plot.add('AL', lst)
SVG(scatter_plot.render())

# %%
scatter_plot = pg.XY(stroke = False , x_title = 'Population_Density', \
                    y_title = 'Poverty')
scatter_plot.title = 'Population Density vs Poverty correlation'
scatter_plot.add('AL', lst)
SVG(scatter_plot.render())

# %%
data_for_tx = dem_health_data.loc[dem_health_data['State'] == 'TX', \
                                 ['Population_Density', 'Poverty']]
data_for_tx.head()
# Out:
#       Population_Density  Poverty
# 2521                  53     20.1
# 2522                   8     15.0
# 2523                 102     17.3
# 2524                  98     18.5
# 2525                  10      9.1

# %%
lst2 = [tuple(x) for x in data_for_tx.values]

# %%
lst2
# Out:
# [(53.0, 20.100000000000001),
#  (8.0, 15.0),
#  (102.0, 17.300000000000001),
#  (98.0, 18.5),
#  (10.0, 9.0999999999999996),
#  (2.0, 9.6999999999999993),
#  (35.0, 19.0),
#  (40.0, 11.300000000000001),
#  (8.0, 17.899999999999999),
#  (25.0, 12.4),
#  (79.0, 12.6),
#  (4.0, 16.699999999999999),
#  (37.0, 24.600000000000001),
#  (242.0, 14.800000000000001),
#  (1218.0, 17.600000000000001),
#  (13.0, 10.5),
#  (1.0, 6.9000000000000004),
#  (18.0, 14.300000000000001),
#  (102.0, 17.5),
#  (201.0, 11.5),
#  (267.0, 18.899999999999999),
#  (1.0, 17.5),
#  (2.0, 15.699999999999999),
#  (8.0, 29.5),
#  (41.0, 18.100000000000001),
#  (26.0, 15.5),
#  (42.0, 11.9),
#  (67.0, 14.699999999999999),
#  (40.0, 16.300000000000001),
#  (15.0, 14.300000000000001),
#  (418.0, 29.5),
#  (62.0, 18.199999999999999),
#  (7.0, 9.0),
#  (32.0, 17.399999999999999),
#  (9.0, 19.699999999999999),
#  (47.0, 10.6),
#  (46.0, 18.199999999999999),
#  (11.0, 21.199999999999999),
#  (10.0, 11.1),
# ...

# %%
scatter_plot = pg.XY(stroke = False , x_title = 'Population_Density', \
                    y_title = 'Poverty')
scatter_plot.title = 'Population Density vs Poverty correlation'
scatter_plot.title = ('AL', lst)
scatter_plot.add('TX', lst2)
SVG(scatter_plot.render())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-99e4d9efeca7> in <module>()
#       3 scatter_plot.title = ('AL', lst)
#       4 scatter_plot.add('TX', lst2)
# ----> 5 SVG(scatter_plot.render())
#
# C:\Users\Hemanth\Anaconda3\lib\site-packages\pygal\graph\public.py in render(self, is_unicode, **kwargs)
#      50     def render(self, is_unicode=False, **kwargs):
#      51         """Render the graph, and return the svg string"""
# ---> 52         self.setup(**kwargs)
#      53         svg = self.svg.render(
#      54             is_unicode=is_unicode, pretty_print=self.pretty_print)
#
# C:\Users\Hemanth\Anaconda3\lib\site-packages\pygal\graph\base.py in setup(self, **kwargs)
#     192             len(self.series)) or []
#     193         self.horizontal = getattr(self, 'horizontal', False)
# --> 194         self.svg = Svg(self)
# ...

# %%
for i in range(0,6,2):
    print(i)
# Out:
# 0
# 2
# 4

# %%
from pygal.style import LightSolarizedStyle
chart = pg.StackedLine(fill=True, interpolate='cubic', style=LightSolarizedStyle)
chart.add('A', [1, 3,  5, 16, 13, 3,  7])
chart.add('B', [5, 2,  3,  2,  5, 7, 17])
chart.add('C', [6, 10, 9,  7,  3, 1,  0])
chart.add('D', [2,  3, 5,  9, 12, 9,  5])
chart.add('E', [7,  4, 2,  1,  2, 10, 0])
SVG(chart.render())

# %%
al = dem_health_data.loc[dem_health_data['State'] == 'AL', ['Poverty']]
poverty_mean_al = al['Poverty'].mean()
poverty_mean_al
# Out:
# 17.085074626865676

# %%
def mean_of_column (state_name, column_name):
    state_df = dem_health_data.loc[dem_health_data['State'] == state_name, [column_name]]
    return state_df[column_name].mean()
mean_of_column('TX', 'Poverty')
# Out:
# 16.793307086614174

# %%
bar_chart = pg.Bar()
bar_chart.title = 'Mean of poverty across all states'
for state in list(dem_health_data['State'].unique()):
    bar_chart.add(state,mean_of_column(state, 'Poverty'))
SVG(bar_chart.render())

# %%
help unique()
# Out:
#   File "<ipython-input-64-127e1602fcdd>", line 1
#     help unique()
#               ^
# SyntaxError: invalid syntax

# %%
pydoc -k unique()
# Out:
#   File "<ipython-input-66-779d3f46461f>", line 1
#     pydoc -k unique()
#                   ^
# SyntaxError: invalid syntax

# %%
help(my_list)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-67-16e52efcf981> in <module>()
# ----> 1 help(my_list)
#
# NameError: name 'my_list' is not defined

# %%
bar_chart = pg.HorizontalBar()
bar_chart.title = 'Mean of poverty across all states'
for state in list(dem_health_data['State'].unique()):
    bar_chart.add(state,mean_of_column(state, 'Poverty'))
SVG(bar_chart.render())

# %%
bar_chart = pg.HorizontalBar(legend_at_bottom = True, \
                            legend_at_bottom_columns = 11)
bar_chart.title = 'Mean of poverty across all states'
for state in list(dem_health_data['State'].unique()):
    bar_chart.add(state,mean_of_column(state, 'Poverty'))
SVG(bar_chart.render())
